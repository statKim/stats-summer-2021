# %% [markdown]
# # Matplotlib

# %%
# 라이브러리 불러오기
import matplotlib.pyplot as plt
import numpy as np

# 그래프를 노트북 안에 그리기 위한 설정
# %matplotlib inline

# %% [markdown]
# # 5. 다양한 그래프 그리는 법
# ## 선그래프

# %%
plt.plot([1, 4, 9, 16])
plt.show()

# %% [markdown]
# ## 산점도 (Scatter plot)
# - `plt.scatter()`
# - 옵션
#     - `marker` : 모양 설정
#     - `c` : 색깔 지정
#     - `s` : 점 크기 지정

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.show()

# %%
# 점 모양 변경
plt.scatter(x, y, marker = ">")  
plt.show()

# %%
# 점 색 지정 + 컬러바 추가
colormap = x

plt.scatter(x, y, c = colormap)  
plt.colorbar()
plt.show()

# %%
# 점 크기 지정
colormap = x
pt_size = (15 * np.random.rand(100))**2

plt.scatter(x, y, c = colormap, s = pt_size)  
plt.colorbar()
plt.show()

# %% [markdown]
# ## 막대 그래프 (bar chart)
# - `plt.bar()`
# - 옵션
#     - `width` : 막대 너비 조절

# %%
x = np.arange(0, 10)
y = np.random.rand(10)

plt.bar(x, y)
plt.show()

# %%
# 막대 여러개 그리기
z = abs(np.random.randn(10))

plt.bar(x, y, color = "r", width = 0.3, label = "A")
plt.bar(x+0.4, y*z, color = "g", width = 0.3, label = "B")  # x+0.4 : x에 0.4를 더한 위치에 그려라
plt.xlabel("data")
plt.ylabel("value")
plt.legend()
plt.show()

# %%
# 막대 가로로 그리기
plt.barh(x, y, color = "r", label = "A")
plt.barh(x, y*z, color = "g", label = "B")
plt.xlabel("data")
plt.ylabel("value")
plt.legend()
plt.show()

# %%
# 막대 여러개 그리기
plt.barh(x, y, color = "r", label = "A")
plt.barh(x, -y*z, color = "g", label = "B")
plt.xlabel("data")
plt.ylabel("value")
plt.legend()
plt.show()

# %% [markdown]
# ## 히스토그램
# - `hist()`
# - 옵션
#     - `bins` : 구간의 개수 조절

# %%
data = np.random.randn(1000)

plt.hist(data)
plt.show()

# %%
# bin 조절
plt.hist(data, bins = 30)
plt.show()

# %% [markdown]
# ## box 플랏 (box plot)

# %%
data = np.random.randn(100)

plt.boxplot(data)
plt.show()

# %%
# boxplot 여러개 그리기
data = np.random.randn(100, 5)

plt.boxplot(data)
plt.show()

# %% [markdown]
# ## 파이 차트 (pie chart)
# - `pie()`

# %%
data = [15, 30, 45, 10]
plt.pie(data)
plt.show()

# %% [markdown]
# # 6. pandas로 그래프 그리기
# - `데이터프레임.plot()`을 사용하며 여러 속성을 가지고 있음
# - `bar`, `pie`, `hist`, `box`, `scatter` 등
# - 기본적으로 열 마다 그래프를 그려줌

# %% [markdown]
# ## 선 그래프 예시

# %%
import pandas as pd

np.random.seed(0)
df1 = pd.DataFrame(np.random.randn(100, 3),
                   index = pd.date_range('1/1/2020', periods=100),
                   columns = ['A', 'B', 'C']).cumsum()
df1.head()
# Out:
#                    A         B         C
# 2020-01-01  1.764052  0.400157  0.978738
# 2020-01-02  4.004946  2.267715  0.001460
# 2020-01-03  4.955034  2.116358 -0.101759
# 2020-01-04  5.365632  2.260402  1.352515
# 2020-01-05  6.126670  2.382077  1.796378

# %%
df1.plot()
plt.xlabel("Time")
plt.ylabel("Data")
plt.show()

# %% [markdown]
# ## 파이차트 예시
# - iris 데이터에서 species의 종류로 파이차트를 그림

# %%
import pandas as pd

iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = iris.species.value_counts()
df
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
df.plot.pie(autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ## 박스플랏 예시
# - iris 데이터에서 연속형 변수 4개에 대한 boxplot

# %%
iris.plot.box()
plt.show()

# %%
iris.boxplot(by = "species")
plt.show()

# %% [markdown]
# ## 막대 그래프 예시
# - iris 데이터에서 연속형 변수 4개에 대한 평균을 막대 그래프로 표현

# %%
df = iris.groupby("species").mean()
df
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df.plot.bar(rot = 0)
plt.show()
